# %% [markdown]
# # Happines Score & Titanic survive Second phase practice project -- Fliprobo

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
import math
% matplotlib in line.
# Out:
# UsageError: Line magic function `%` not found.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.drop(['Country','Region'],axis=1, inplace = True)

# %%
df
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
plt.figure(figsize=(13,11))
sns.heatmap(df.corr(),annot = True)
plt.show()

# %%
df.isnull()
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0             False            False           False
# 1             False            False           False
# 2             False            False           False
# 3             False            False           False
# 4             False            False           False
# ..              ...              ...             ...
# 153           False            False           False
# 154           False            False           False
# 155           False            False           False
# 156           False            False           False
# 157           False            False           False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 0                       False   False                     False    False
# 1                       False   False                     False    False
# 2                       False   False                     False    False
# ...

# %%
df.isnull().sum()
# Out:
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.dtypes
# Out:
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
y = df['Happiness Score']
x = df.drop('Happiness Score',axis =1)

# %%
Scaler = MinMaxScaler()
x = pd.DataFrame(Scaler.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#      Happiness Rank  Standard Error  Economy (GDP per Capita)    Family  \
# 0          0.000000        0.131954                  0.826132  0.962403
# 1          0.006369        0.256311                  0.770412  1.000000
# 2          0.012739        0.124947                  0.784113  0.970297
# 3          0.019108        0.171549                  0.863099  0.949167
# 4          0.025478        0.143943                  0.784592  0.943219
# ..              ...             ...                       ...       ...
# 153        0.974522        0.136429                  0.131376  0.551764
# 154        0.980892        0.152638                  0.169573  0.252355
# 155        0.987261        0.267370                  0.392329  0.338668
# 156        0.993631        0.574926                  0.009051  0.296578
# 157        1.000000        0.411904                  0.123449  0.099805
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, train_size = 0.7)

# %% [markdown]
# Training

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(f'Regression R2:{model.score(x_test,y_test)}')
# Out:
# Regression R2:0.9999999184502872

# %% [markdown]
# # Titanic survived Project

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Analyze the data

sns.countplot(x= 'Survived', data = df1)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = 'Survived',hue = 'Sex',data = df1)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x = 'Survived',hue = 'Pclass',data = df1)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %% [markdown]
# passanger did not survived belongs to the 3rd class

# %%
df1['Age'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# the max age group travelling in the ship is between 20-40. very few of old age

# %%
df1['Fare'].plot.hist(bins=20,figsize = (10,5))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# most of the tickets are bought under 0-100

# %%
sns.countplot(x = 'SibSp',data = df1)
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %% [markdown]
# most of the passengers have come without their siblings

# %%
df1['Parch'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Data wrangling -- cleaning the data

# %%
df1.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dtypes
# Out:
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# age and cabin has the most null values.

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Pclass',y='Age',data =df1)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.drop('Cabin',axis =1,inplace = True)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
df1.dropna(inplace=True)

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
#we will convert string values into catagorical to apply linear regression

pd.get_dummies(df1['Sex'])
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 885       1     0
# 886       0     1
# 887       1     0
# 889       0     1
# 890       0     1
#
# [712 rows x 2 columns]

# %%
sex = pd.get_dummies(df1['Sex'],drop_first =True)

# %%
sex
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 885     0
# 886     1
# 887     0
# 889     1
# 890     1
#
# [712 rows x 1 columns]

# %%
# we have dropped one column because only one column is enough to determine the gender

# %%
embark = pd.get_dummies(df1['Embarked'])

# %%
embark
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 885  0  1  0
# 886  0  0  1
# 887  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [712 rows x 3 columns]

# %% [markdown]
# c stands for cherbourg, q stands fro queenstown and s stands for southhampton.
#
# we can drop one of the column as we can identify with other two itself

# %%
embark = pd.get_dummies(df1['Embarked'],drop_first = True)

# %%
embark
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 885  1  0
# 886  0  1
# 887  0  1
# 889  0  0
# 890  1  0
#
# [712 rows x 2 columns]

# %%
pcl = pd.get_dummies(df1['Pclass'],drop_first = True)

# %%
pcl
# Out:
#      2  3
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  0
# 4    0  1
# ..  .. ..
# 885  0  1
# 886  1  0
# 887  0  0
# 889  0  0
# 890  0  1
#
# [712 rows x 2 columns]

# %%
df1 = pd.concat([df1,sex,embark,pcl],axis = 1)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.drop(['Name','Sex','Ticket','Pclass','Sex','Embarked'],inplace = True,axis = 1)

# %%
df1
# Out:
#      PassengerId  Survived   Age  SibSp  Parch     Fare  male  Q  S  2  3
# 0              1         0  22.0      1      0   7.2500     1  0  1  0  1
# 1              2         1  38.0      1      0  71.2833     0  0  0  0  0
# 2              3         1  26.0      0      0   7.9250     0  0  1  0  1
# 3              4         1  35.0      1      0  53.1000     0  0  1  0  0
# 4              5         0  35.0      0      0   8.0500     1  0  1  0  1
# ..           ...       ...   ...    ...    ...      ...   ... .. .. .. ..
# 885          886         0  39.0      0      5  29.1250     0  1  0  0  1
# 886          887         0  27.0      0      0  13.0000     1  0  1  1  0
# 887          888         1  19.0      0      0  30.0000     0  0  1  0  0
# 889          890         1  26.0      0      0  30.0000     1  0  0  0  0
# 890          891         0  32.0      0      0   7.7500     1  1  0  0  1
#
# [712 rows x 11 columns]

# %% [markdown]
# # Train Data

# %%
x = df1.drop('Survived',axis= 1)
y = df1['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.33, random_state = 4)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lm=LogisticRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report

# %%
prediction = lm.predict(x_test)

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import classification_report

# %%
confusion_matrix(y_test,prediction)
# Out:
# array([[125,  20],
#        [ 32,  58]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,prediction)
# Out:
# 0.7787234042553192

# %% [markdown]
# overall accuracy is 78%
